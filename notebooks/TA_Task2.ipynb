# %%
import yfinance as yf
from src.indicators.ta_indicators import add_basic_ta

ticker = 'AAPL'
p = yf.download(ticker, start='2020-01-01', end='2025-11-25')
p = add_basic_ta(p)
p[['Adj Close', 'SMA_10', 'RSI_14']].tail()

# Plot SMA and RSI
p['Adj Close'].plot(title=f'{ticker} Adj Close & SMA_10')
p['SMA_10'].plot()
plt.show()
